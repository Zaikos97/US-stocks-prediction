# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns',250)
from sklearn.impute import KNNImputer
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score
from numpy import mean
from numpy import std
from sklearn.metrics import accuracy_score, precision_score, recall_score
from tqdm import tqdm
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import f1_score
from sklearn.decomposition import PCA
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn import metrics
import matplotlib.pyplot as plt

# %%
train=pd.read_csv(r'C:\Users\Admin\Desktop\US-stocks-prediction\Cleaning\train.csv')
test=pd.read_csv(r'C:\Users\Admin\Desktop\US-stocks-prediction\Cleaning\test.csv')

# %%
x=train.groupby('Class').count()
x
# Out:
#        Revenue  Revenue Growth  Cost of Revenue  Gross Profit  R&D Expenses  \
# Class
# 0.0       8572            8572             8572          8572          8572
# 1.0       9113            9113             9113          9113          9113
#
#        SG&A Expense  Operating Expenses  Operating Income  Interest Expense  \
# Class
# 0.0            8572                8572              8572              8572
# 1.0            9113                9113              9113              9113
#
#        Earnings before Tax  Income Tax Expense  \
# Class
# 0.0                   8572                8572
# 1.0                   9113                9113
#
#        Net Income - Non-Controlling int  Net Income - Discontinued ops  \
# Class
# 0.0                                8572                           8572
# 1.0                                9113                           9113
#
#        Net Income  Preferred Dividends  Net Income Com   EPS  EPS Diluted  \
# Class
# 0.0          8572                 8572            8572  8572         8572
# 1.0          9113                 9113            9113  9113         9113
#
#        Weighted Average Shs Out  Weighted Average Shs Out (Dil)  \
# Class
# 0.0                        8572                            8572
# 1.0                        9113                            9113
#
#        Dividend per Share  Gross Margin  EBITDA Margin  EBIT Margin  \
# Class
# 0.0                  8572          8572           8572         8572
# 1.0                  9113          9113           9113         9113
#
#        Profit Margin  Free Cash Flow margin  EBITDA  EBIT  \
# Class
# 0.0             8572                   8572    8572  8572
# 1.0             9113                   9113    9113  9113
#
#        Consolidated Income  Earnings Before Tax Margin  Net Profit Margin  \
# Class
# 0.0                   8572                        8572               8572
# 1.0                   9113                        9113               9113
#
#        Cash and cash equivalents  Short-term investments  \
# Class
# 0.0                         8572                    8572
# 1.0                         9113                    9113
#
#        Cash and short-term investments  Receivables  Inventories  \
# Class
# 0.0                               8572         8572         8572
# 1.0                               9113         9113         9113
#
#        Total current assets  Property, Plant & Equipment Net  \
# Class
# 0.0                    8572                             8572
# 1.0                    9113                             9113
#
#        Goodwill and Intangible Assets  Long-term investments  Tax assets  \
# Class
# 0.0                              8572                   8572        8572
# 1.0                              9113                   9113        9113
#
#        Total non-current assets  Total assets  Payables  Short-term debt  \
# Class
# 0.0                        8572          8572      8572             8572
# 1.0                        9113          9113      9113             9113
#
#        Total current liabilities  Long-term debt  Total debt  \
# Class
# 0.0                         8572            8572        8572
# 1.0                         9113            9113        9113
#
#        Deferred revenue  Tax Liabilities  Deposit Liabilities  \
# Class
# 0.0                8572             8572                 8572
# 1.0                9113             9113                 9113
#
#        Total non-current liabilities  Total liabilities  \
# Class
# 0.0                             8572               8572
# 1.0                             9113               9113
#
#        Other comprehensive income  Retained earnings (deficit)  \
# Class
# 0.0                          8572                         8572
# 1.0                          9113                         9113
#
#        Total shareholders equity  Investments  Net Debt  Other Assets  \
# Class
# 0.0                         8572         8572      8572          8572
# 1.0                         9113         9113      9113          9113
#
#        Other Liabilities  Depreciation & Amortization  \
# Class
# 0.0                 8572                         8572
# 1.0                 9113                         9113
#
#        Stock-based compensation  Operating Cash Flow  Capital Expenditure  \
# Class
# 0.0                        8572                 8572                 8572
# 1.0                        9113                 9113                 9113
#
#        Acquisitions and disposals  Investment purchases and sales  \
# Class
# 0.0                          8572                            8572
# 1.0                          9113                            9113
#
#        Investing Cash flow  Issuance (repayment) of debt  \
# Class
# 0.0                   8572                          8572
# 1.0                   9113                          9113
#
#        Issuance (buybacks) of shares  Dividend payments  Financing Cash Flow  \
# Class
# 0.0                             8572               8572                 8572
# 1.0                             9113               9113                 9113
#
#        Effect of forex changes on cash  Net cash flow / Change in cash  \
# Class
# 0.0                               8572                            8572
# 1.0                               9113                            9113
#
#        Free Cash Flow  Net Cash/Marketcap  priceBookValueRatio  \
# Class
# 0.0              8572                8572                 8572
# 1.0              9113                9113                 9113
#
#        priceToBookRatio  priceToSalesRatio  priceEarningsRatio  \
# Class
# 0.0                8572               8572                8572
# 1.0                9113               9113                9113
#
#        priceToFreeCashFlowsRatio  priceToOperatingCashFlowsRatio  \
# Class
# 0.0                         8572                            8572
# 1.0                         9113                            9113
#
#        priceCashFlowRatio  priceEarningsToGrowthRatio  priceSalesRatio  \
# Class
# 0.0                  8572                        8572             8572
# 1.0                  9113                        9113             9113
#
#        dividendYield  enterpriseValueMultiple  priceFairValue  ebitperRevenue  \
# Class
# 0.0             8572                     8572            8572            8572
# 1.0             9113                     9113            9113            9113
#
#        ebtperEBIT  niperEBT  grossProfitMargin  operatingProfitMargin  \
# Class
# 0.0          8572      8572               8572                   8572
# 1.0          9113      9113               9113                   9113
#
#        pretaxProfitMargin  netProfitMargin  effectiveTaxRate  returnOnAssets  \
# Class
# 0.0                  8572             8572              8572            8572
# 1.0                  9113             9113              9113            9113
#
#        returnOnEquity  returnOnCapitalEmployed  nIperEBT  eBTperEBIT  \
# Class
# 0.0              8572                     8572      8572        8572
# 1.0              9113                     9113      9113        9113
#
#        eBITperRevenue  payablesTurnover  inventoryTurnover  \
# Class
# 0.0              8572              8572               8572
# 1.0              9113              9113               9113
#
#        fixedAssetTurnover  assetTurnover  currentRatio  quickRatio  cashRatio  \
# Class
# 0.0                  8572           8572          8572        8572       8572
# 1.0                  9113           9113          9113        9113       9113
#
#        daysOfSalesOutstanding  daysOfInventoryOutstanding  operatingCycle  \
# Class
# 0.0                      8572                        8572            8572
# 1.0                      9113                        9113            9113
#
#        daysOfPayablesOutstanding  cashConversionCycle  debtRatio  \
# Class
# 0.0                         8572                 8572       8572
# 1.0                         9113                 9113       9113
#
#        debtEquityRatio  longtermDebtToCapitalization  \
# Class
# 0.0               8572                          8572
# 1.0               9113                          9113
#
#        totalDebtToCapitalization  interestCoverage  cashFlowToDebtRatio  \
# Class
# 0.0                         8572              8572                 8572
# 1.0                         9113              9113                 9113
#
#        companyEquityMultiplier  operatingCashFlowPerShare  \
# Class
# 0.0                       8572                       8572
# 1.0                       9113                       9113
#
#        freeCashFlowPerShare  cashPerShare  payoutRatio  \
# Class
# 0.0                    8572          8572         8572
# 1.0                    9113          9113         9113
#
#        operatingCashFlowSalesRatio  freeCashFlowOperatingCashFlowRatio  \
# Class
# 0.0                           8572                                8572
# 1.0                           9113                                9113
#
#        cashFlowCoverageRatios  shortTermCoverageRatios  \
# Class
# 0.0                      8572                     8572
# 1.0                      9113                     9113
#
#        capitalExpenditureCoverageRatios  dividendpaidAndCapexCoverageRatios  \
# Class
# 0.0                                8572                                8572
# 1.0                                9113                                9113
#
#        dividendPayoutRatio  Revenue per Share  Net Income per Share  \
# Class
# 0.0                   8572               8572                  8572
# 1.0                   9113               9113                  9113
#
#        Operating Cash Flow per Share  Free Cash Flow per Share  \
# Class
# 0.0                             8572                      8572
# 1.0                             9113                      9113
#
#        Cash per Share  Book Value per Share  Tangible Book Value per Share  \
# Class
# 0.0              8572                  8572                           8572
# 1.0              9113                  9113                           9113
#
#        Shareholders Equity per Share  Interest Debt per Share  Market Cap  \
# Class
# 0.0                             8572                     8572        8572
# 1.0                             9113                     9113        9113
#
#        Enterprise Value  PE ratio  Price to Sales Ratio  POCF ratio  \
# Class
# 0.0                8572      8572                  8572        8572
# 1.0                9113      9113                  9113        9113
#
#        PFCF ratio  PB ratio  PTB ratio  EV to Sales  \
# Class
# 0.0          8572      8572       8572         8572
# 1.0          9113      9113       9113         9113
#
#        Enterprise Value over EBITDA  EV to Operating cash flow  \
# Class
# 0.0                            8572                       8572
# 1.0                            9113                       9113
#
#        EV to Free cash flow  Earnings Yield  Free Cash Flow Yield  \
# Class
# 0.0                    8572            8572                  8572
# 1.0                    9113            9113                  9113
#
#        Debt to Equity  Debt to Assets  Net Debt to EBITDA  Current ratio  \
# Class
# 0.0              8572            8572                8572           8572
# 1.0              9113            9113                9113           9113
#
#        Interest Coverage  Income Quality  Dividend Yield  Payout Ratio  \
# Class
# 0.0                 8572            8572            8572          8572
# 1.0                 9113            9113            9113          9113
#
#        SG&A to Revenue  R&D to Revenue  Intangibles to Total Assets  \
# Class
# 0.0               8572            8572                         8572
# 1.0               9113            9113                         9113
#
#        Capex to Operating Cash Flow  Capex to Revenue  Capex to Depreciation  \
# Class
# 0.0                            8572              8572                   8572
# 1.0                            9113              9113                   9113
#
#        Stock-based compensation to Revenue  Graham Number  ROIC  \
# Class
# 0.0                                   8572           8572  8572
# 1.0                                   9113           9113  9113
#
#        Return on Tangible Assets  Graham Net-Net  Working Capital  \
# Class
# 0.0                         8572            8572             8572
# 1.0                         9113            9113             9113
#
#        Tangible Asset Value  Net Current Asset Value  Invested Capital  \
# Class
# 0.0                    8572                     8572              8572
# 1.0                    9113                     9113              9113
#
#        Average Receivables  Average Payables  Average Inventory  \
# Class
# 0.0                   8572              8572               8572
# 1.0                   9113              9113               9113
#
#        Days Sales Outstanding  Days Payables Outstanding  \
# Class
# 0.0                      8572                       8572
# 1.0                      9113                       9113
#
#        Days of Inventory on Hand  Receivables Turnover  Payables Turnover  \
# Class
# 0.0                         8572                  8572               8572
# 1.0                         9113                  9113               9113
#
#        Inventory Turnover   ROE  Capex per Share  Gross Profit Growth  \
# Class
# 0.0                  8572  8572             8572                 8572
# 1.0                  9113  9113             9113                 9113
#
#        EBIT Growth  Operating Income Growth  Net Income Growth  EPS Growth  \
# Class
# 0.0           8572                     8572               8572        8572
# 1.0           9113                     9113               9113        9113
#
#        EPS Diluted Growth  Weighted Average Shares Growth  \
# Class
# 0.0                  8572                            8572
# 1.0                  9113                            9113
#
#        Weighted Average Shares Diluted Growth  Dividends per Share Growth  \
# Class
# 0.0                                      8572                        8572
# 1.0                                      9113                        9113
#
#        Operating Cash Flow growth  Free Cash Flow growth  \
# Class
# 0.0                          8572                   8572
# 1.0                          9113                   9113
#
#        10Y Revenue Growth (per Share)  5Y Revenue Growth (per Share)  \
# Class
# 0.0                              8572                           8572
# 1.0                              9113                           9113
#
#        3Y Revenue Growth (per Share)  10Y Operating CF Growth (per Share)  \
# Class
# 0.0                             8572                                 8572
# 1.0                             9113                                 9113
#
#        5Y Operating CF Growth (per Share)  3Y Operating CF Growth (per Share)  \
# Class
# 0.0                                  8572                                8572
# 1.0                                  9113                                9113
#
#        10Y Net Income Growth (per Share)  5Y Net Income Growth (per Share)  \
# Class
# 0.0                                 8572                              8572
# 1.0                                 9113                              9113
#
#        3Y Net Income Growth (per Share)  \
# Class
# 0.0                                8572
# 1.0                                9113
#
#        10Y Shareholders Equity Growth (per Share)  \
# Class
# 0.0                                          8572
# 1.0                                          9113
#
#        5Y Shareholders Equity Growth (per Share)  \
# Class
# 0.0                                         8572
# 1.0                                         9113
#
#        3Y Shareholders Equity Growth (per Share)  \
# Class
# 0.0                                         8572
# 1.0                                         9113
#
#        10Y Dividend per Share Growth (per Share)  \
# Class
# 0.0                                         8572
# 1.0                                         9113
#
#        5Y Dividend per Share Growth (per Share)  \
# Class
# 0.0                                        8572
# 1.0                                        9113
#
#        3Y Dividend per Share Growth (per Share)  Receivables growth  \
# Class
# 0.0                                        8572                8572
# 1.0                                        9113                9113
#
#        Inventory Growth  Asset Growth  Book Value per Share Growth  \
# Class
# 0.0                8572          8572                         8572
# 1.0                9113          9113                         9113
#
#        Debt Growth  R&D Expense Growth  SG&A Expenses Growth  PRICE_VAR  \
# Class
# 0.0           8572                8572                  8572       8572
# 1.0           9113                9113                  9113       9113
#
#        Sector_Basic Materials  Sector_Communication Services  \
# Class
# 0.0                      8572                           8572
# 1.0                      9113                           9113
#
#        Sector_Consumer Cyclical  Sector_Consumer Defensive  Sector_Energy  \
# Class
# 0.0                        8572                       8572           8572
# 1.0                        9113                       9113           9113
#
#        Sector_Financial Services  Sector_Healthcare  Sector_Industrials  \
# Class
# 0.0                         8572               8572                8572
# 1.0                         9113               9113                9113
#
#        Sector_Real Estate  Sector_Technology  Sector_Utilities
# Class
# 0.0                  8572               8572              8572
# 1.0                  9113               9113              9113

# %%
x=x.reset_index()
x=x.rename(columns={'Revenue':'Count'})

# %%
x.plot.bar(x='Class', y='Count', rot=0,color=(0.85,0.52,0.48,0.66))
# Out:
# <AxesSubplot:xlabel='Class'>

# %%
X_train=train.drop(['Class','PRICE_VAR'],1)
y_train=train['Class']
X_test=test.drop(['Class','PRICE_VAR'],1)
y_test=test['Class']

# %%
cor_matrix = X_train.corr().abs()
upper_tri = cor_matrix.where(np.triu(np.ones(cor_matrix.shape),k=1).astype(np.bool))
print(upper_tri)
# Out:
#                     Revenue  Revenue Growth  Cost of Revenue  Gross Profit  \
# Revenue                 NaN        0.001959         0.978758      0.806340
# Revenue Growth          NaN             NaN         0.001541      0.002820
# Cost of Revenue         NaN             NaN              NaN      0.677541
# Gross Profit            NaN             NaN              NaN           NaN
# R&D Expenses            NaN             NaN              NaN           NaN
# ...                     ...             ...              ...           ...
# Sector_Healthcare       NaN             NaN              NaN           NaN
# Sector_Industrials      NaN             NaN              NaN           NaN
# Sector_Real Estate      NaN             NaN              NaN           NaN
# Sector_Technology       NaN             NaN              NaN           NaN
# Sector_Utilities        NaN             NaN              NaN           NaN
#
#                     R&D Expenses  SG&A Expense  Operating Expenses  \
# Revenue                 0.347895      0.567751            0.560801
# Revenue Growth          0.001603      0.003016            0.003049
# Cost of Revenue         0.296248      0.433000            0.409923
# Gross Profit            0.418327      0.840669            0.882899
# R&D Expenses                 NaN      0.260219            0.351134
# ...                          ...           ...                 ...
# Sector_Healthcare            NaN           NaN                 NaN
# Sector_Industrials           NaN           NaN                 NaN
# Sector_Real Estate           NaN           NaN                 NaN
# Sector_Technology            NaN           NaN                 NaN
# Sector_Utilities             NaN           NaN                 NaN
#
#                     Operating Income  Interest Expense  Earnings before Tax  \
# Revenue                     0.452557          0.641648             0.430803
# Revenue Growth              0.002582          0.002406             0.002494
# Cost of Revenue             0.308969          0.584209             0.295052
# Gross Profit                0.777017          0.657724             0.735087
# R&D Expenses                0.347439          0.179940             0.428322
# ...                              ...               ...                  ...
# Sector_Healthcare                NaN               NaN                  NaN
# Sector_Industrials               NaN               NaN                  NaN
# Sector_Real Estate               NaN               NaN                  NaN
# Sector_Technology                NaN               NaN                  NaN
# Sector_Utilities                 NaN               NaN                  NaN
#
#                     Income Tax Expense  Net Income - Non-Controlling int  \
# Revenue                       0.053883                          0.190401
# Revenue Growth                0.000192                          0.001180
# Cost of Revenue               0.043492                          0.141581
# Gross Profit                  0.072009                          0.285024
# R&D Expenses                  0.035602                          0.049754
# ...                                ...                               ...
# Sector_Healthcare                  NaN                               NaN
# Sector_Industrials                 NaN                               NaN
# Sector_Real Estate                 NaN                               NaN
# Sector_Technology                  NaN                               NaN
# Sector_Utilities                   NaN                               NaN
#
#                     Net Income - Discontinued ops  Net Income  \
# Revenue                                  0.009851    0.374290
# Revenue Growth                           0.000073    0.001805
# Cost of Revenue                          0.012425    0.293293
# Gross Profit                             0.001184    0.528705
# R&D Expenses                             0.064252    0.328918
# ...                                           ...         ...
# Sector_Healthcare                             NaN         NaN
# Sector_Industrials                            NaN         NaN
# Sector_Real Estate                            NaN         NaN
# Sector_Technology                             NaN         NaN
# Sector_Utilities                              NaN         NaN
#
#                     Preferred Dividends  Net Income Com       EPS  \
# Revenue                        0.134083        0.372052  0.001987
# Revenue Growth                 0.001232        0.001847  0.000147
# Cost of Revenue                0.100009        0.292002  0.001565
# Gross Profit                   0.212307        0.524540  0.002857
# R&D Expenses                   0.027350        0.322254  0.001632
# ...                                 ...             ...       ...
# Sector_Healthcare                   NaN             NaN       NaN
# Sector_Industrials                  NaN             NaN       NaN
# Sector_Real Estate                  NaN             NaN       NaN
# Sector_Technology                   NaN             NaN       NaN
# Sector_Utilities                    NaN             NaN       NaN
#
#                     EPS Diluted  Weighted Average Shs Out  \
# Revenue                0.002003                  0.174713
# Revenue Growth         0.000149                  0.001592
# Cost of Revenue        0.001578                  0.125111
# Gross Profit           0.002878                  0.281716
# R&D Expenses           0.001647                  0.124615
# ...                         ...                       ...
# Sector_Healthcare           NaN                       NaN
# Sector_Industrials          NaN                       NaN
# Sector_Real Estate          NaN                       NaN
# Sector_Technology           NaN                       NaN
# Sector_Utilities            NaN                       NaN
#
#                     Weighted Average Shs Out (Dil)  Dividend per Share  \
# Revenue                                   0.162788            0.000335
# Revenue Growth                            0.001524            0.000233
# Cost of Revenue                           0.115476            0.000263
# Gross Profit                              0.259741            0.000404
# R&D Expenses                              0.115402            0.000557
# ...                                            ...                 ...
# Sector_Healthcare                              NaN                 NaN
# Sector_Industrials                             NaN                 NaN
# Sector_Real Estate                             NaN                 NaN
# Sector_Technology                              NaN                 NaN
# Sector_Utilities                               NaN                 NaN
#
#                     Gross Margin  EBITDA Margin  EBIT Margin  Profit Margin  \
# Revenue                 0.016264       0.007352     0.004961       0.007511
# Revenue Growth          0.000235       0.000237     0.000404       0.000203
# Cost of Revenue         0.025610       0.005748     0.003893       0.005879
# Gross Profit            0.018039       0.010637     0.007180       0.010847
# R&D Expenses            0.008370       0.004314     0.002746       0.004433
# ...                          ...            ...          ...            ...
# Sector_Healthcare            NaN            NaN          NaN            NaN
# Sector_Industrials           NaN            NaN          NaN            NaN
# Sector_Real Estate           NaN            NaN          NaN            NaN
# Sector_Technology            NaN            NaN          NaN            NaN
# Sector_Utilities             NaN            NaN          NaN            NaN
#
#                     Free Cash Flow margin    EBITDA      EBIT  \
# Revenue                          0.004480  0.805759  0.533484
# Revenue Growth                   0.000423  0.002618  0.002318
# Cost of Revenue                  0.003527  0.702522  0.434407
# Gross Profit                     0.006461  0.921111  0.701660
# R&D Expenses                     0.002552  0.442184  0.377575
# ...                                   ...       ...       ...
# Sector_Healthcare                     NaN       NaN       NaN
# Sector_Industrials                    NaN       NaN       NaN
# Sector_Real Estate                    NaN       NaN       NaN
# Sector_Technology                     NaN       NaN       NaN
# Sector_Utilities                      NaN       NaN       NaN
#
#                     Consolidated Income  Earnings Before Tax Margin  \
# Revenue                        0.378987                    0.005054
# Revenue Growth                 0.001855                    0.000402
# Cost of Revenue                0.296684                    0.003979
# Gross Profit                   0.537106                    0.007315
# R&D Expenses                   0.328377                    0.002811
# ...                                 ...                         ...
# Sector_Healthcare                   NaN                         NaN
# Sector_Industrials                  NaN                         NaN
# Sector_Real Estate                  NaN                         NaN
# Sector_Technology                   NaN                         NaN
# Sector_Utilities                    NaN                         NaN
#
#                     Net Profit Margin  Cash and cash equivalents  \
# Revenue                      0.004933                   0.192673
# Revenue Growth               0.000309                   0.001249
# Cost of Revenue              0.003875                   0.127221
# Gross Profit                 0.007121                   0.344299
# R&D Expenses                 0.002747                   0.101445
# ...                               ...                        ...
# Sector_Healthcare                 NaN                        NaN
# Sector_Industrials                NaN                        NaN
# Sector_Real Estate                NaN                        NaN
# Sector_Technology                 NaN                        NaN
# Sector_Utilities                  NaN                        NaN
#
#                     Short-term investments  Cash and short-term investments  \
# Revenue                           0.059091                         0.084799
# Revenue Growth                    0.000976                         0.001295
# Cost of Revenue                   0.018934                         0.027300
# Gross Profit                      0.168233                         0.236632
# R&D Expenses                      0.053571                         0.069332
# ...                                    ...                              ...
# Sector_Healthcare                      NaN                              NaN
# Sector_Industrials                     NaN                              NaN
# Sector_Real Estate                     NaN                              NaN
# Sector_Technology                      NaN                              NaN
# Sector_Utilities                       NaN                              NaN
#
#                     Receivables  Inventories  Total current assets  \
# Revenue                0.229688     0.895608              0.488802
# Revenue Growth         0.001748     0.000858              0.001616
# Cost of Revenue        0.181823     0.930092              0.419204
# Gross Profit           0.322273     0.564583              0.583579
# R&D Expenses           0.135325     0.268441              0.162551
# ...                         ...          ...                   ...
# Sector_Healthcare           NaN          NaN                   NaN
# Sector_Industrials          NaN          NaN                   NaN
# Sector_Real Estate          NaN          NaN                   NaN
# Sector_Technology           NaN          NaN                   NaN
# Sector_Utilities            NaN          NaN                   NaN
#
#                     Property, Plant & Equipment Net  \
# Revenue                                    0.896531
# Revenue Growth                             0.001866
# Cost of Revenue                            0.871989
# Gross Profit                               0.744076
# R&D Expenses                               0.276859
# ...                                             ...
# Sector_Healthcare                               NaN
# Sector_Industrials                              NaN
# Sector_Real Estate                              NaN
# Sector_Technology                               NaN
# Sector_Utilities                                NaN
#
#                     Goodwill and Intangible Assets  Long-term investments  \
# Revenue                                   0.275513               0.065011
# Revenue Growth                            0.002582               0.001146
# Cost of Revenue                           0.172173               0.035406
# Gross Profit                              0.527775               0.139100
# R&D Expenses                              0.258695               0.023135
# ...                                            ...                    ...
# Sector_Healthcare                              NaN                    NaN
# Sector_Industrials                             NaN                    NaN
# Sector_Real Estate                             NaN                    NaN
# Sector_Technology                              NaN                    NaN
# Sector_Utilities                               NaN                    NaN
#
#                     Tax assets  Total non-current assets  Total assets  \
# Revenue               0.247618                  0.011135      0.259349
# Revenue Growth        0.001668                  0.000845      0.001382
# Cost of Revenue       0.175633                  0.008713      0.205978
# Gross Profit          0.405192                  0.015900      0.357741
# R&D Expenses          0.136446                  0.010477      0.078499
# ...                        ...                       ...           ...
# Sector_Healthcare          NaN                       NaN           NaN
# Sector_Industrials         NaN                       NaN           NaN
# Sector_Real Estate         NaN                       NaN           NaN
# Sector_Technology          NaN                       NaN           NaN
# Sector_Utilities           NaN                       NaN           NaN
#
#                     Payables  Short-term debt  Total current liabilities  \
# Revenue             0.760698         0.681380                   0.244400
# Revenue Growth      0.001395         0.001560                   0.001503
# Cost of Revenue     0.731951         0.658825                   0.177956
# Gross Profit        0.660991         0.579588                   0.394513
# R&D Expenses        0.222328         0.199162                   0.057277
# ...                      ...              ...                        ...
# Sector_Healthcare        NaN              NaN                        NaN
# Sector_Industrials       NaN              NaN                        NaN
# Sector_Real Estate       NaN              NaN                        NaN
# Sector_Technology        NaN              NaN                        NaN
# Sector_Utilities         NaN              NaN                        NaN
#
#                     Long-term debt  Total debt  Deferred revenue  \
# Revenue                   0.269730    0.268401          0.011192
# Revenue Growth            0.001138    0.001401          0.000849
# Cost of Revenue           0.237824    0.214927          0.008757
# Gross Profit              0.298731    0.363833          0.015984
# R&D Expenses              0.083391    0.076943          0.010523
# ...                            ...         ...               ...
# Sector_Healthcare              NaN         NaN               NaN
# Sector_Industrials             NaN         NaN               NaN
# Sector_Real Estate             NaN         NaN               NaN
# Sector_Technology              NaN         NaN               NaN
# Sector_Utilities               NaN         NaN               NaN
#
#                     Tax Liabilities  Deposit Liabilities  \
# Revenue                    0.011192             0.256095
# Revenue Growth             0.000850             0.001336
# Cost of Revenue            0.008757             0.189358
# Gross Profit               0.015984             0.396083
# R&D Expenses               0.010523             0.037442
# ...                             ...                  ...
# Sector_Healthcare               NaN                  NaN
# Sector_Industrials              NaN                  NaN
# Sector_Real Estate              NaN                  NaN
# Sector_Technology               NaN                  NaN
# Sector_Utilities                NaN                  NaN
#
#                     Total non-current liabilities  Total liabilities  \
# Revenue                                  0.011108           0.208272
# Revenue Growth                           0.000846           0.001187
# Cost of Revenue                          0.008688           0.156176
# Gross Profit                             0.015870           0.316265
# R&D Expenses                             0.010468           0.048496
# ...                                           ...                ...
# Sector_Healthcare                             NaN                NaN
# Sector_Industrials                            NaN                NaN
# Sector_Real Estate                            NaN                NaN
# Sector_Technology                             NaN                NaN
# Sector_Utilities                              NaN                NaN
#
#                     Other comprehensive income  Retained earnings (deficit)  \
# Revenue                               0.011146                     0.593039
# Revenue Growth                        0.000846                     0.001888
# Cost of Revenue                       0.008721                     0.524553
# Gross Profit                          0.015914                     0.652002
# R&D Expenses                          0.010484                     0.331778
# ...                                        ...                          ...
# Sector_Healthcare                          NaN                          NaN
# Sector_Industrials                         NaN                          NaN
# Sector_Real Estate                         NaN                          NaN
# Sector_Technology                          NaN                          NaN
# Sector_Utilities                           NaN                          NaN
#
#                     Total shareholders equity  Investments  Net Debt  \
# Revenue                              0.669516     0.277530  0.294319
# Revenue Growth                       0.002294     0.001646  0.001057
# Cost of Revenue                      0.608834     0.210552  0.273742
# Gross Profit                         0.687969     0.418214  0.282271
# R&D Expenses                         0.335736     0.054420  0.044116
# ...                                       ...          ...       ...
# Sector_Healthcare                         NaN          NaN       NaN
# Sector_Industrials                        NaN          NaN       NaN
# Sector_Real Estate                        NaN          NaN       NaN
# Sector_Technology                         NaN          NaN       NaN
# Sector_Utilities                          NaN          NaN       NaN
#
#                     Other Assets  Other Liabilities  \
# Revenue                 0.726860           0.128078
# Revenue Growth          0.000289           0.001211
# Cost of Revenue         0.757475           0.056122
# Gross Profit            0.450974           0.311740
# R&D Expenses            0.201277           0.015810
# ...                          ...                ...
# Sector_Healthcare            NaN                NaN
# Sector_Industrials           NaN                NaN
# Sector_Real Estate           NaN                NaN
# Sector_Technology            NaN                NaN
# Sector_Utilities             NaN                NaN
#
#                     Depreciation & Amortization  Stock-based compensation  \
# Revenue                                0.128744                  0.165562
# Revenue Growth                         0.000753                  0.001782
# Cost of Revenue                        0.097558                  0.100500
# Gross Profit                           0.191897                  0.325718
# R&D Expenses                           0.075417                  0.671395
# ...                                         ...                       ...
# Sector_Healthcare                           NaN                       NaN
# Sector_Industrials                          NaN                       NaN
# Sector_Real Estate                          NaN                       NaN
# Sector_Technology                           NaN                       NaN
# Sector_Utilities                            NaN                       NaN
#
#                     Operating Cash Flow  Capital Expenditure  \
# Revenue                        0.184237             0.777498
# Revenue Growth                 0.000759             0.001821
# Cost of Revenue                0.162155             0.722650
# Gross Profit                   0.207428             0.746406
# R&D Expenses                   0.102752             0.280817
# ...                                 ...                  ...
# Sector_Healthcare                   NaN                  NaN
# Sector_Industrials                  NaN                  NaN
# Sector_Real Estate                  NaN                  NaN
# Sector_Technology                   NaN                  NaN
# Sector_Utilities                    NaN                  NaN
#
#                     Acquisitions and disposals  \
# Revenue                               0.064476
# Revenue Growth                        0.000975
# Cost of Revenue                       0.037098
# Gross Profit                          0.135876
# R&D Expenses                          0.162179
# ...                                        ...
# Sector_Healthcare                          NaN
# Sector_Industrials                         NaN
# Sector_Real Estate                         NaN
# Sector_Technology                          NaN
# Sector_Utilities                           NaN
#
#                     Investment purchases and sales  Investing Cash flow  \
# Revenue                                   0.020821             0.450363
# Revenue Growth                            0.000663             0.001456
# Cost of Revenue                           0.060508             0.385583
# Gross Profit                              0.112598             0.533000
# R&D Expenses                              0.067952             0.244241
# ...                                            ...                  ...
# Sector_Healthcare                              NaN                  NaN
# Sector_Industrials                             NaN                  NaN
# Sector_Real Estate                             NaN                  NaN
# Sector_Technology                              NaN                  NaN
# Sector_Utilities                               NaN                  NaN
#
#                     Issuance (repayment) of debt  \
# Revenue                                 0.502446
# Revenue Growth                          0.000227
# Cost of Revenue                         0.534440
# Gross Profit                            0.274789
# R&D Expenses                            0.063960
# ...                                          ...
# Sector_Healthcare                            NaN
# Sector_Industrials                           NaN
# Sector_Real Estate                           NaN
# Sector_Technology                            NaN
# Sector_Utilities                             NaN
#
#                     Issuance (buybacks) of shares  Dividend payments  \
# Revenue                                  0.215597           0.403501
# Revenue Growth                           0.001015           0.002987
# Cost of Revenue                          0.156973           0.291095
# Gross Profit                             0.339569           0.645655
# R&D Expenses                             0.242190           0.410588
# ...                                           ...                ...
# Sector_Healthcare                             NaN                NaN
# Sector_Industrials                            NaN                NaN
# Sector_Real Estate                            NaN                NaN
# Sector_Technology                             NaN                NaN
# Sector_Utilities                              NaN                NaN
#
#                     Financing Cash Flow  Effect of forex changes on cash  \
# Revenue                        0.056130                         0.000874
# Revenue Growth                 0.000114                         0.000226
# Cost of Revenue                0.054403                         0.001026
# Gross Profit                   0.048137                         0.000537
# R&D Expenses                   0.035203                         0.002694
# ...                                 ...                              ...
# Sector_Healthcare                   NaN                              NaN
# Sector_Industrials                  NaN                              NaN
# Sector_Real Estate                  NaN                              NaN
# Sector_Technology                   NaN                              NaN
# Sector_Utilities                    NaN                              NaN
#
#                     Net cash flow / Change in cash  Free Cash Flow  \
# Revenue                                   0.007396        0.405932
# Revenue Growth                            0.000195        0.002008
# Cost of Revenue                           0.005437        0.318656
# Gross Profit                              0.012568        0.577422
# R&D Expenses                              0.000218        0.343349
# ...                                            ...             ...
# Sector_Healthcare                              NaN             NaN
# Sector_Industrials                             NaN             NaN
# Sector_Real Estate                             NaN             NaN
# Sector_Technology                              NaN             NaN
# Sector_Utilities                               NaN             NaN
#
#                     Net Cash/Marketcap  priceBookValueRatio  priceToBookRatio  \
# Revenue                       0.002174             0.005546          0.005545
# Revenue Growth                0.000292             0.000443          0.000443
# Cost of Revenue               0.001872             0.004385          0.004385
# Gross Profit                  0.002623             0.007914          0.007914
# R&D Expenses                  0.002574             0.004964          0.004964
# ...                                ...                  ...               ...
# Sector_Healthcare                  NaN                  NaN               NaN
# Sector_Industrials                 NaN                  NaN               NaN
# Sector_Real Estate                 NaN                  NaN               NaN
# Sector_Technology                  NaN                  NaN               NaN
# Sector_Utilities                   NaN                  NaN               NaN
#
#                     priceToSalesRatio  priceEarningsRatio  \
# Revenue                      0.003886            0.000282
# Revenue Growth               0.000160            0.000556
# Cost of Revenue              0.003075            0.000783
# Gross Profit                 0.005550            0.000636
# R&D Expenses                 0.002416            0.000607
# ...                               ...                 ...
# Sector_Healthcare                 NaN                 NaN
# Sector_Industrials                NaN                 NaN
# Sector_Real Estate                NaN                 NaN
# Sector_Technology                 NaN                 NaN
# Sector_Utilities                  NaN                 NaN
#
#                     priceToFreeCashFlowsRatio  priceToOperatingCashFlowsRatio  \
# Revenue                              0.001453                        0.000171
# Revenue Growth                       0.000705                        0.000283
# Cost of Revenue                      0.002608                        0.000676
# Gross Profit                         0.002439                        0.001351
# R&D Expenses                         0.002168                        0.001137
# ...                                       ...                             ...
# Sector_Healthcare                         NaN                             NaN
# Sector_Industrials                        NaN                             NaN
# Sector_Real Estate                        NaN                             NaN
# Sector_Technology                         NaN                             NaN
# Sector_Utilities                          NaN                             NaN
#
#                     priceCashFlowRatio  priceEarningsToGrowthRatio  \
# Revenue                       0.011691                    0.001973
# Revenue Growth                0.001020                    0.000943
# Cost of Revenue               0.008147                    0.000900
# Gross Profit                  0.018311                    0.004987
# R&D Expenses                  0.006175                    0.000391
# ...                                ...                         ...
# Sector_Healthcare                  NaN                         NaN
# Sector_Industrials                 NaN                         NaN
# Sector_Real Estate                 NaN                         NaN
# Sector_Technology                  NaN                         NaN
# Sector_Utilities                   NaN                         NaN
#
#                     priceSalesRatio  dividendYield  enterpriseValueMultiple  \
# Revenue                    0.005273       0.019197                 0.007199
# Revenue Growth             0.000440       0.000436                 0.000116
# Cost of Revenue            0.004162       0.014314                 0.005295
# Gross Profit               0.007550       0.028049                 0.011715
# R&D Expenses               0.003281       0.000067                 0.006032
# ...                             ...            ...                      ...
# Sector_Healthcare               NaN            NaN                      NaN
# Sector_Industrials              NaN            NaN                      NaN
# Sector_Real Estate              NaN            NaN                      NaN
# Sector_Technology               NaN            NaN                      NaN
# Sector_Utilities                NaN            NaN                      NaN
#
#                     priceFairValue  ebitperRevenue  ebtperEBIT  niperEBT  \
# Revenue                   0.006775        0.007492    0.000915  0.003087
# Revenue Growth            0.000502        0.000107    0.000075  0.000385
# Cost of Revenue           0.005323        0.005888    0.000699  0.002807
# Gross Profit              0.009667        0.010811    0.001407  0.003220
# R&D Expenses              0.006075        0.004524    0.001287  0.002481
# ...                            ...             ...         ...       ...
# Sector_Healthcare              NaN             NaN         NaN       NaN
# Sector_Industrials             NaN             NaN         NaN       NaN
# Sector_Real Estate             NaN             NaN         NaN       NaN
# Sector_Technology              NaN             NaN         NaN       NaN
# Sector_Utilities               NaN             NaN         NaN       NaN
#
#                     grossProfitMargin  operatingProfitMargin  \
# Revenue                      0.002291                    NaN
# Revenue Growth               0.000051                    NaN
# Cost of Revenue              0.006532                    NaN
# Gross Profit                 0.011767                    NaN
# R&D Expenses                 0.006012                    NaN
# ...                               ...                    ...
# Sector_Healthcare                 NaN                    NaN
# Sector_Industrials                NaN                    NaN
# Sector_Real Estate                NaN                    NaN
# Sector_Technology                 NaN                    NaN
# Sector_Utilities                  NaN                    NaN
#
#                     pretaxProfitMargin  netProfitMargin  effectiveTaxRate  \
# Revenue                       0.007608         0.007487          0.001175
# Revenue Growth                0.000098         0.000016          0.000082
# Cost of Revenue               0.005992         0.005888          0.001007
# Gross Profit                  0.010929         0.010790          0.001643
# R&D Expenses                  0.004534         0.004538          0.000919
# ...                                ...              ...               ...
# Sector_Healthcare                  NaN              NaN               NaN
# Sector_Industrials                 NaN              NaN               NaN
# Sector_Real Estate                 NaN              NaN               NaN
# Sector_Technology                  NaN              NaN               NaN
# Sector_Utilities                   NaN              NaN               NaN
#
#                     returnOnAssets  returnOnEquity  returnOnCapitalEmployed  \
# Revenue                   0.003732        0.004370                 0.000676
# Revenue Growth            0.001445        0.000357                 0.000351
# Cost of Revenue           0.002571        0.003457                 0.000835
# Gross Profit              0.006330        0.006238                 0.000011
# R&D Expenses              0.004843        0.003883                 0.000584
# ...                            ...             ...                      ...
# Sector_Healthcare              NaN             NaN                      NaN
# Sector_Industrials             NaN             NaN                      NaN
# Sector_Real Estate             NaN             NaN                      NaN
# Sector_Technology              NaN             NaN                      NaN
# Sector_Utilities               NaN             NaN                      NaN
#
#                     nIperEBT  eBTperEBIT  eBITperRevenue  payablesTurnover  \
# Revenue             0.003087    0.000915        0.007492          0.010545
# Revenue Growth      0.000385    0.000075        0.000107          0.000283
# Cost of Revenue     0.002807    0.000699        0.005888          0.008577
# Gross Profit        0.003220    0.001407        0.010811          0.013638
# R&D Expenses        0.002481    0.001287        0.004524          0.003277
# ...                      ...         ...             ...               ...
# Sector_Healthcare        NaN         NaN             NaN               NaN
# Sector_Industrials       NaN         NaN             NaN               NaN
# Sector_Real Estate       NaN         NaN             NaN               NaN
# Sector_Technology        NaN         NaN             NaN               NaN
# Sector_Utilities         NaN         NaN             NaN               NaN
#
#                     inventoryTurnover  fixedAssetTurnover  assetTurnover  \
# Revenue                      0.003413            0.005843       0.026160
# Revenue Growth               0.001140            0.000463       0.001417
# Cost of Revenue              0.002897            0.004522       0.034994
# Gross Profit                 0.003376            0.008522       0.008548
# R&D Expenses                 0.000570            0.005440       0.012912
# ...                               ...                 ...            ...
# Sector_Healthcare                 NaN                 NaN            NaN
# Sector_Industrials                NaN                 NaN            NaN
# Sector_Real Estate                NaN                 NaN            NaN
# Sector_Technology                 NaN                 NaN            NaN
# Sector_Utilities                  NaN                 NaN            NaN
#
#                     currentRatio  quickRatio  cashRatio  \
# Revenue                 0.002956    0.001634   0.001045
# Revenue Growth          0.001125    0.000159   0.000164
# Cost of Revenue         0.001205    0.001856   0.001461
# Gross Profit            0.007489    0.002173   0.001194
# R&D Expenses            0.000408    0.002111   0.001619
# ...                          ...         ...        ...
# Sector_Healthcare            NaN         NaN        NaN
# Sector_Industrials           NaN         NaN        NaN
# Sector_Real Estate           NaN         NaN        NaN
# Sector_Technology            NaN         NaN        NaN
# Sector_Utilities             NaN         NaN        NaN
#
#                     daysOfSalesOutstanding  daysOfInventoryOutstanding  \
# Revenue                           0.003850                    0.054547
# Revenue Growth                    0.000069                    0.000391
# Cost of Revenue                   0.003066                    0.060017
# Gross Profit                      0.005224                    0.033944
# R&D Expenses                      0.002670                    0.017397
# ...                                    ...                         ...
# Sector_Healthcare                      NaN                         NaN
# Sector_Industrials                     NaN                         NaN
# Sector_Real Estate                     NaN                         NaN
# Sector_Technology                      NaN                         NaN
# Sector_Utilities                       NaN                         NaN
#
#                     operatingCycle  daysOfPayablesOutstanding  \
# Revenue                   0.022857                   0.003969
# Revenue Growth            0.004352                   0.000865
# Cost of Revenue           0.019200                   0.003280
# Gross Profit              0.030029                   0.005242
# R&D Expenses              0.001334                   0.002864
# ...                            ...                        ...
# Sector_Healthcare              NaN                        NaN
# Sector_Industrials             NaN                        NaN
# Sector_Real Estate             NaN                        NaN
# Sector_Technology              NaN                        NaN
# Sector_Utilities               NaN                        NaN
#
#                     cashConversionCycle  debtRatio  debtEquityRatio  \
# Revenue                        0.063753   0.000193         0.003629
# Revenue Growth                 0.005498   0.000270         0.000164
# Cost of Revenue                0.053316   0.000153         0.002973
# Gross Profit                   0.091246   0.000613         0.004227
# R&D Expenses                   0.033925   0.005280         0.002432
# ...                                 ...        ...              ...
# Sector_Healthcare                   NaN        NaN              NaN
# Sector_Industrials                  NaN        NaN              NaN
# Sector_Real Estate                  NaN        NaN              NaN
# Sector_Technology                   NaN        NaN              NaN
# Sector_Utilities                    NaN        NaN              NaN
#
#                     longtermDebtToCapitalization  totalDebtToCapitalization  \
# Revenue                                 0.007916                   0.000029
# Revenue Growth                          0.000461                   0.000109
# Cost of Revenue                         0.007904                   0.000207
# Gross Profit                            0.007525                   0.000788
# R&D Expenses                            0.002564                   0.001375
# ...                                          ...                        ...
# Sector_Healthcare                            NaN                        NaN
# Sector_Industrials                           NaN                        NaN
# Sector_Real Estate                           NaN                        NaN
# Sector_Technology                            NaN                        NaN
# Sector_Utilities                             NaN                        NaN
#
#                     interestCoverage  cashFlowToDebtRatio  \
# Revenue                     0.003044             0.001196
# Revenue Growth              0.001924             0.000002
# Cost of Revenue             0.002310             0.000891
# Gross Profit                0.004607             0.001943
# R&D Expenses                0.002052             0.001109
# ...                              ...                  ...
# Sector_Healthcare                NaN                  NaN
# Sector_Industrials               NaN                  NaN
# Sector_Real Estate               NaN                  NaN
# Sector_Technology                NaN                  NaN
# Sector_Utilities                 NaN                  NaN
#
#                     companyEquityMultiplier  operatingCashFlowPerShare  \
# Revenue                            0.007283                   0.022281
# Revenue Growth                     0.000564                   0.000567
# Cost of Revenue                    0.005734                   0.020931
# Gross Profit                       0.010395                   0.020217
# R&D Expenses                       0.006542                   0.005429
# ...                                     ...                        ...
# Sector_Healthcare                       NaN                        NaN
# Sector_Industrials                      NaN                        NaN
# Sector_Real Estate                      NaN                        NaN
# Sector_Technology                       NaN                        NaN
# Sector_Utilities                        NaN                        NaN
#
#                     freeCashFlowPerShare  cashPerShare  payoutRatio  \
# Revenue                         0.000257      0.000539     0.001145
# Revenue Growth                  0.000211      0.000461     0.000715
# Cost of Revenue                 0.000029      0.000051     0.000203
# Gross Profit                    0.001229      0.004184     0.002465
# R&D Expenses                    0.000078      0.002184     0.002174
# ...                                  ...           ...          ...
# Sector_Healthcare                    NaN           NaN          NaN
# Sector_Industrials                   NaN           NaN          NaN
# Sector_Real Estate                   NaN           NaN          NaN
# Sector_Technology                    NaN           NaN          NaN
# Sector_Utilities                     NaN           NaN          NaN
#
#                     operatingCashFlowSalesRatio  \
# Revenue                                0.000294
# Revenue Growth                         0.000032
# Cost of Revenue                        0.000212
# Gross Profit                           0.000408
# R&D Expenses                           0.000412
# ...                                         ...
# Sector_Healthcare                           NaN
# Sector_Industrials                          NaN
# Sector_Real Estate                          NaN
# Sector_Technology                           NaN
# Sector_Utilities                            NaN
#
#                     freeCashFlowOperatingCashFlowRatio  \
# Revenue                                       0.008728
# Revenue Growth                                0.000331
# Cost of Revenue                               0.006419
# Gross Profit                                  0.014277
# R&D Expenses                                  0.009339
# ...                                                ...
# Sector_Healthcare                                  NaN
# Sector_Industrials                                 NaN
# Sector_Real Estate                                 NaN
# Sector_Technology                                  NaN
# Sector_Utilities                                   NaN
#
#                     cashFlowCoverageRatios  shortTermCoverageRatios  \
# Revenue                           0.001196                 0.002204
# Revenue Growth                    0.000002                 0.000226
# Cost of Revenue                   0.000891                 0.001999
# Gross Profit                      0.001943                 0.002349
# R&D Expenses                      0.001109                 0.002870
# ...                                    ...                      ...
# Sector_Healthcare                      NaN                      NaN
# Sector_Industrials                     NaN                      NaN
# Sector_Real Estate                     NaN                      NaN
# Sector_Technology                      NaN                      NaN
# Sector_Utilities                       NaN                      NaN
#
#                     capitalExpenditureCoverageRatios  \
# Revenue                                     0.001439
# Revenue Growth                              0.000442
# Cost of Revenue                             0.000912
# Gross Profit                                0.002707
# R&D Expenses                                0.000478
# ...                                              ...
# Sector_Healthcare                                NaN
# Sector_Industrials                               NaN
# Sector_Real Estate                               NaN
# Sector_Technology                                NaN
# Sector_Utilities                                 NaN
#
#                     dividendpaidAndCapexCoverageRatios  dividendPayoutRatio  \
# Revenue                                       0.007144             0.000784
# Revenue Growth                                0.001145             0.000702
# Cost of Revenue                               0.005650             0.000014
# Gross Profit                                  0.010106             0.002151
# R&D Expenses                                  0.004164             0.001404
# ...                                                ...                  ...
# Sector_Healthcare                                  NaN                  NaN
# Sector_Industrials                                 NaN                  NaN
# Sector_Real Estate                                 NaN                  NaN
# Sector_Technology                                  NaN                  NaN
# Sector_Utilities                                   NaN                  NaN
#
#                     Revenue per Share  Net Income per Share  \
# Revenue                      0.029207              0.010176
# Revenue Growth               0.000529              0.000488
# Cost of Revenue              0.028312              0.008788
# Gross Profit                 0.020561              0.012540
# R&D Expenses                 0.004902              0.001464
# ...                               ...                   ...
# Sector_Healthcare                 NaN                   NaN
# Sector_Industrials                NaN                   NaN
# Sector_Real Estate                NaN                   NaN
# Sector_Technology                 NaN                   NaN
# Sector_Utilities                  NaN                   NaN
#
#                     Operating Cash Flow per Share  Free Cash Flow per Share  \
# Revenue                                  0.022277                  0.000257
# ...
# Gross Profit                             0.008803
# R&D Expenses                             0.011547
# ...                                           ...
# Sector_Healthcare                             NaN
# Sector_Industrials                            NaN
# Sector_Real Estate                            NaN
# Sector_Technology                             NaN
# Sector_Utilities                              NaN
#
#                     10Y Operating CF Growth (per Share)  \
# Revenue                                        0.025758
# Revenue Growth                                 0.008835
# Cost of Revenue                                0.016897
# Gross Profit                                   0.044243
# R&D Expenses                                   0.080175
# ...                                                 ...
# Sector_Healthcare                                   NaN
# Sector_Industrials                                  NaN
# Sector_Real Estate                                  NaN
# Sector_Technology                                   NaN
# Sector_Utilities                                    NaN
#
#                     5Y Operating CF Growth (per Share)  \
# Revenue                                       0.010686
# Revenue Growth                                0.003034
# Cost of Revenue                               0.008970
# Gross Profit                                  0.016348
# R&D Expenses                                  0.028188
# ...                                                ...
# Sector_Healthcare                                  NaN
# Sector_Industrials                                 NaN
# Sector_Real Estate                                 NaN
# Sector_Technology                                  NaN
# Sector_Utilities                                   NaN
#
#                     3Y Operating CF Growth (per Share)  \
# Revenue                                       0.005379
# Revenue Growth                                0.002497
# Cost of Revenue                               0.005350
# Gross Profit                                  0.004306
# R&D Expenses                                  0.013061
# ...                                                ...
# Sector_Healthcare                                  NaN
# Sector_Industrials                                 NaN
# Sector_Real Estate                                 NaN
# Sector_Technology                                  NaN
# Sector_Utilities                                   NaN
#
#                     10Y Net Income Growth (per Share)  \
# Revenue                                      0.017824
# Revenue Growth                               0.004978
# Cost of Revenue                              0.011930
# Gross Profit                                 0.038968
# R&D Expenses                                 0.064559
# ...                                               ...
# Sector_Healthcare                                 NaN
# Sector_Industrials                                NaN
# Sector_Real Estate                                NaN
# Sector_Technology                                 NaN
# Sector_Utilities                                  NaN
#
#                     5Y Net Income Growth (per Share)  \
# Revenue                                     0.008506
# Revenue Growth                              0.004419
# Cost of Revenue                             0.003326
# Gross Profit                                0.023849
# R&D Expenses                                0.004344
# ...                                              ...
# Sector_Healthcare                                NaN
# Sector_Industrials                               NaN
# Sector_Real Estate                               NaN
# Sector_Technology                                NaN
# Sector_Utilities                                 NaN
#
#                     3Y Net Income Growth (per Share)  \
# Revenue                                     0.007229
# Revenue Growth                              0.002486
# Cost of Revenue                             0.003906
# Gross Profit                                0.017372
# R&D Expenses                                0.003501
# ...                                              ...
# Sector_Healthcare                                NaN
# Sector_Industrials                               NaN
# Sector_Real Estate                               NaN
# Sector_Technology                                NaN
# Sector_Utilities                                 NaN
#
#                     10Y Shareholders Equity Growth (per Share)  \
# Revenue                                               0.039630
# Revenue Growth                                        0.009408
# Cost of Revenue                                       0.029320
# Gross Profit                                          0.065119
# R&D Expenses                                          0.083890
# ...                                                        ...
# Sector_Healthcare                                          NaN
# Sector_Industrials                                         NaN
# Sector_Real Estate                                         NaN
# Sector_Technology                                          NaN
# Sector_Utilities                                           NaN
#
#                     5Y Shareholders Equity Growth (per Share)  \
# Revenue                                              0.010307
# Revenue Growth                                       0.000615
# Cost of Revenue                                      0.006457
# Gross Profit                                         0.020695
# R&D Expenses                                         0.028824
# ...                                                       ...
# Sector_Healthcare                                         NaN
# Sector_Industrials                                        NaN
# Sector_Real Estate                                        NaN
# Sector_Technology                                         NaN
# Sector_Utilities                                          NaN
#
#                     3Y Shareholders Equity Growth (per Share)  \
# Revenue                                              0.003540
# Revenue Growth                                       0.005560
# Cost of Revenue                                      0.001709
# Gross Profit                                         0.010445
# R&D Expenses                                         0.009759
# ...                                                       ...
# Sector_Healthcare                                         NaN
# Sector_Industrials                                        NaN
# Sector_Real Estate                                        NaN
# Sector_Technology                                         NaN
# Sector_Utilities                                          NaN
#
#                     10Y Dividend per Share Growth (per Share)  \
# Revenue                                              0.034658
# Revenue Growth                                       0.008596
# Cost of Revenue                                      0.028280
# Gross Profit                                         0.047861
# R&D Expenses                                         0.041644
# ...                                                       ...
# Sector_Healthcare                                         NaN
# Sector_Industrials                                        NaN
# Sector_Real Estate                                        NaN
# Sector_Technology                                         NaN
# Sector_Utilities                                          NaN
#
#                     5Y Dividend per Share Growth (per Share)  \
# Revenue                                             0.042883
# Revenue Growth                                      0.000612
# Cost of Revenue                                     0.031912
# Gross Profit                                        0.066252
# R&D Expenses                                        0.032643
# ...                                                      ...
# Sector_Healthcare                                        NaN
# Sector_Industrials                                       NaN
# Sector_Real Estate                                       NaN
# Sector_Technology                                        NaN
# Sector_Utilities                                         NaN
#
#                     3Y Dividend per Share Growth (per Share)  \
# Revenue                                             0.033972
# Revenue Growth                                      0.001132
# Cost of Revenue                                     0.026831
# Gross Profit                                        0.048934
# R&D Expenses                                        0.022098
# ...                                                      ...
# Sector_Healthcare                                        NaN
# Sector_Industrials                                       NaN
# Sector_Real Estate                                       NaN
# Sector_Technology                                        NaN
# Sector_Utilities                                         NaN
#
#                     Receivables growth  Inventory Growth  Asset Growth  \
# Revenue                       0.002199          0.006161      0.003713
# Revenue Growth                0.034084          0.021395      0.000295
# Cost of Revenue               0.001370          0.004683      0.002922
# Gross Profit                  0.004553          0.009223      0.005315
# R&D Expenses                  0.003809          0.002593      0.002976
# ...                                ...               ...           ...
# Sector_Healthcare                  NaN               NaN           NaN
# Sector_Industrials                 NaN               NaN           NaN
# Sector_Real Estate                 NaN               NaN           NaN
# Sector_Technology                  NaN               NaN           NaN
# Sector_Utilities                   NaN               NaN           NaN
#
#                     Book Value per Share Growth  Debt Growth  \
# Revenue                                0.011213     0.004107
# Revenue Growth                         0.000801     0.003566
# Cost of Revenue                        0.008821     0.003261
# Gross Profit                           0.015868     0.005931
# R&D Expenses                           0.010454     0.001470
# ...                                         ...          ...
# Sector_Healthcare                           NaN          NaN
# Sector_Industrials                          NaN          NaN
# Sector_Real Estate                          NaN          NaN
# Sector_Technology                           NaN          NaN
# Sector_Utilities                            NaN          NaN
#
#                     R&D Expense Growth  SG&A Expenses Growth  \
# Revenue                       0.003981              0.003543
# Revenue Growth                0.000474              0.000323
# Cost of Revenue               0.003168              0.002785
# Gross Profit                  0.005611              0.005069
# R&D Expenses                  0.001626              0.002508
# ...                                ...                   ...
# Sector_Healthcare                  NaN                   NaN
# Sector_Industrials                 NaN                   NaN
# Sector_Real Estate                 NaN                   NaN
# Sector_Technology                  NaN                   NaN
# Sector_Utilities                   NaN                   NaN
#
#                     Sector_Basic Materials  Sector_Communication Services  \
# Revenue                           0.012749                       0.056321
# Revenue Growth                    0.003097                       0.001826
# Cost of Revenue                   0.006792                       0.021298
# Gross Profit                      0.029982                       0.144124
# R&D Expenses                      0.025586                       0.009586
# ...                                    ...                            ...
# Sector_Healthcare                      NaN                            NaN
# Sector_Industrials                     NaN                            NaN
# Sector_Real Estate                     NaN                            NaN
# Sector_Technology                      NaN                            NaN
# Sector_Utilities                       NaN                            NaN
#
#                     Sector_Consumer Cyclical  Sector_Consumer Defensive  \
# Revenue                             0.005792                   0.042199
# Revenue Growth                      0.004277                   0.003391
# Cost of Revenue                     0.008122                   0.038043
# Gross Profit                        0.005107                   0.043146
# R&D Expenses                        0.026574                   0.027261
# ...                                      ...                        ...
# Sector_Healthcare                        NaN                        NaN
# Sector_Industrials                       NaN                        NaN
# Sector_Real Estate                       NaN                        NaN
# Sector_Technology                        NaN                        NaN
# Sector_Utilities                         NaN                        NaN
#
#                     Sector_Energy  Sector_Financial Services  \
# Revenue                  0.045983                   0.005963
# Revenue Growth           0.002737                   0.011146
# Cost of Revenue          0.048343                   0.000998
# Gross Profit             0.025949                   0.031094
# R&D Expenses             0.002741                   0.053014
# ...                           ...                        ...
# Sector_Healthcare             NaN                        NaN
# Sector_Industrials            NaN                        NaN
# Sector_Real Estate            NaN                        NaN
# Sector_Technology             NaN                        NaN
# Sector_Utilities              NaN                        NaN
#
#                     Sector_Healthcare  Sector_Industrials  Sector_Real Estate  \
# Revenue                      0.024412            0.015898            0.031364
# Revenue Growth               0.004572            0.004453            0.002552
# Cost of Revenue              0.019210            0.011559            0.025730
# Gross Profit                 0.035646            0.025579            0.041714
# R&D Expenses                 0.056116            0.029031            0.032854
# ...                               ...                 ...                 ...
# Sector_Healthcare                 NaN            0.156733            0.101199
# Sector_Industrials                NaN                 NaN            0.091447
# Sector_Real Estate                NaN                 NaN                 NaN
# Sector_Technology                 NaN                 NaN                 NaN
# Sector_Utilities                  NaN                 NaN                 NaN
#
#                     Sector_Technology  Sector_Utilities
# Revenue                      0.020080          0.000368
# Revenue Growth               0.004611          0.001969
# Cost of Revenue              0.018836          0.001116
# Gross Profit                 0.022290          0.003089
# R&D Expenses                 0.123462          0.020999
# ...                               ...               ...
# Sector_Healthcare            0.168590          0.064639
# Sector_Industrials           0.152345          0.058411
# Sector_Real Estate           0.098365          0.037714
# Sector_Technology                 NaN          0.062829
# Sector_Utilities                  NaN               NaN
#
# [232 rows x 232 columns]

# %%
to_drop = [column for column in upper_tri.columns if any(upper_tri[column] > 0.80)]

# %%
to_drop
# Out:
# ['Cost of Revenue',
#  'Gross Profit',
#  'SG&A Expense',
#  'Operating Expenses',
#  'Earnings before Tax',
#  'Net Income Com',
#  'EPS Diluted',
#  'Weighted Average Shs Out (Dil)',
#  'Profit Margin',
#  'Free Cash Flow margin',
#  'EBITDA',
#  'EBIT',
#  'Consolidated Income',
#  'Earnings Before Tax Margin',
#  'Net Profit Margin',
#  'Inventories',
#  'Property, Plant & Equipment Net',
#  'Total current liabilities',
#  'Long-term debt',
#  'Total debt',
#  'Deferred revenue',
#  'Tax Liabilities',
#  'Deposit Liabilities',
#  'Total non-current liabilities',
#  'Total liabilities',
#  'Other comprehensive income',
#  'Total shareholders equity',
#  'Investments',
#  'Net Debt',
#  'Other Assets',
#  'Other Liabilities',
#  'Capital Expenditure',
#  'priceToBookRatio',
#  'priceSalesRatio',
#  'ebitperRevenue',
#  'pretaxProfitMargin',
#  'netProfitMargin',
#  'returnOnEquity',
#  'nIperEBT',
#  'eBTperEBIT',
#  'eBITperRevenue',
#  'cashRatio',
#  'companyEquityMultiplier',
#  'cashFlowCoverageRatios',
#  'Net Income per Share',
#  'Operating Cash Flow per Share',
#  'Free Cash Flow per Share',
#  'Cash per Share',
#  'Tangible Book Value per Share',
#  'Shareholders Equity per Share',
#  'Interest Debt per Share',
#  'PE ratio',
#  'Price to Sales Ratio',
#  'POCF ratio',
#  'PFCF ratio',
#  'PB ratio',
#  'PTB ratio',
#  'Debt to Equity',
#  'Debt to Assets',
#  'Current ratio',
#  'Interest Coverage',
#  'Income Quality',
#  'Payout Ratio',
#  'SG&A to Revenue',
#  'R&D to Revenue',
#  'Capex to Operating Cash Flow',
#  'Capex to Revenue',
#  'Stock-based compensation to Revenue',
#  'ROIC',
#  'Return on Tangible Assets',
#  'Graham Net-Net',
#  'Working Capital',
#  'Tangible Asset Value',
#  'Net Current Asset Value',
#  'Invested Capital',
#  'Average Receivables',
#  'Days Sales Outstanding',
#  'Days Payables Outstanding',
#  'Days of Inventory on Hand',
#  'Payables Turnover',
#  'Inventory Turnover',
#  'ROE',
#  'Gross Profit Growth',
#  'Operating Income Growth',
#  'EPS Diluted Growth',
#  'Asset Growth',
#  'Book Value per Share Growth',
#  'SG&A Expenses Growth']

# %%
X_train=X_train.drop(to_drop, axis=1)
X_test=X_test.drop(to_drop, axis=1)

# %%
X=pd.concat([X_train,X_test])
y=pd.concat([y_train,y_test])

# %%
scalers = [StandardScaler(),MinMaxScaler()]

# %%
for scaler in scalers:    
    model = LogisticRegression(solver='liblinear')
    pipeline = Pipeline([('s',scaler),('m',model)])
    # define the evaluation procedure
    cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
    # evaluate the model
    m_scores = cross_val_score(pipeline, X, y, scoring='accuracy', cv=cv, n_jobs=-1)
    # summarize the result
    print('Accuracy: %.3f (%.3f)' % (mean(m_scores), std(m_scores)))
# Out:
# Accuracy: 0.647 (0.006)
# Accuracy: 0.647 (0.006)

# %%
X_train2=StandardScaler().fit_transform(X_train)
X_train2 = pd.DataFrame(X_train2)
X_train2.columns = list(X_train)
X_test2=StandardScaler().transform(X_test)
X_test2 = pd.DataFrame(X_test2)
X_test2.columns = list(X_test)

# %%
# Logistic Regression
from sklearn.linear_model import LogisticRegression
LR = LogisticRegression(solver='liblinear')

# Decision Trees
from sklearn.tree import DecisionTreeClassifier
DT = DecisionTreeClassifier()
# Random Forest
from sklearn.ensemble import RandomForestClassifier
RF = RandomForestClassifier()
# Naive Bayes
from sklearn.naive_bayes import GaussianNB
NB = GaussianNB()
# K-Nearest Neighbors
from sklearn.neighbors import KNeighborsClassifier
KNN = KNeighborsClassifier()

models = [LR,DT,RF,NB,KNN]

# %%
accuracy, precision, recall = {}, {}, {}

for model in tqdm(models):
    
    # Fit the classifier model
    model.fit(X_train2, y_train)
    
    predictions = model.predict(X_test2)
    
    # Prediction 
    # Calculate Accuracy, Precision and Recall Metrics
    accuracy[model] = accuracy_score(predictions, y_test)
    precision[model] = precision_score(predictions, y_test)
    recall[model] = recall_score(predictions, y_test)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:38<00:00,  7.72s/it]

# %%
df_model = pd.DataFrame(index=models, columns=['Accuracy', 'Precision', 'Recall'])
df_model['Accuracy'] = accuracy.values()
df_model['Precision'] = precision.values()
df_model['Recall'] = recall.values()

df_model
# Out:
#                                                     Accuracy  Precision  \
# LogisticRegression(solver='liblinear')              0.563069   0.594550
# DecisionTreeClassifier()                            0.485428   0.444846
# (DecisionTreeClassifier(max_features='auto', ra...  0.468124   0.395601
# GaussianNB()                                        0.683743   0.959947
# KNeighborsClassifier()                              0.578324   0.581418
#
#                                                       Recall
# LogisticRegression(solver='liblinear')              0.725852
# DecisionTreeClassifier()                            0.704262
# (DecisionTreeClassifier(max_features='auto', ra...  0.708824
# GaussianNB()                                        0.697686
# KNeighborsClassifier()                              0.754259

# %%
params_NB = {'var_smoothing': np.logspace(0,-9, num=100)}
gs_NB = GridSearchCV(estimator=GaussianNB(), 
                 param_grid=params_NB, 
                 cv=cv,   # use any cross validation technique 
                 verbose=1, 
                 scoring='accuracy') 
gs_NB.fit(X_train, y_train)

gs_NB.best_params_
# Out:
# Fitting 30 folds for each of 100 candidates, totalling 3000 fits
# {'var_smoothing': 1e-09}

# %%
param_grid_nb = {
    'var_smoothing': [1e-09]
}
nbModel_grid = GridSearchCV(estimator=GaussianNB(), param_grid=param_grid_nb, verbose=1, cv=10, n_jobs=-1)
nbModel_grid.fit(X_train2, y_train)
y_pred = nbModel_grid.predict(X_test2)
# Out:
# Fitting 10 folds for each of 1 candidates, totalling 10 fits

# %%
print( accuracy_score(y_test,y_pred))
print(precision_score(y_test,y_pred))
print( recall_score(y_test,y_pred))
# Out:
# 0.6837431693989071
# 0.6976855165831544
# 0.9599474720945502

# %%
cf=confusion_matrix(y_test,y_pred)
cf
# Out:
# array([[  79, 1267],
#        [ 122, 2924]], dtype=int64)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.39      0.06      0.10      1346
#          1.0       0.70      0.96      0.81      3046
#
#     accuracy                           0.68      4392
#    macro avg       0.55      0.51      0.46      4392
# weighted avg       0.60      0.68      0.59      4392

# %%
import seaborn as sns
sns.heatmap(cf, annot=True,fmt="d",cmap='viridis')
# Out:
# <AxesSubplot:>
